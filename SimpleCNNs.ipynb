# %% [markdown]
# # Data Loader and Prolem Setting

# %% [markdown]
# # Constructed Model
#
# Constructed CNNs with:
#
# * Layer 1 : Conv 6 filters, size 5x5, stride 1
# * Layer 2 : average pooling 6 kernels, size 2x2, stride 2
# * Layer 3 : Conv 16 filters, size 5x5, stride 1
# * Layer 4 : average pooling 16 kernels, size 2x2, stride 2
# * Layer 5 : FC 120 nodes
# * Layer 6 : FC 84 nodes
# * Layer 7 : output layer 10 nodes

# %% [markdown]
# # Train

# %% [markdown]
# # Evaluation
